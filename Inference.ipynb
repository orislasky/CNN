# %%
#before running please colorize the picture at: https://playback.fm/colorize-photo
import tensorflow as tf 
from tensorflow import keras
import numpy as np
import sys
import time
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import img_to_array, load_img
model = tf.keras.models.load_model('model/')

# %%
# %matplotlib inline

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from cv2 import cvtColor

originalImage = mpimg.imread("brain/0/N6.jpg")
image = cv2.imread("brain/0/N6.jpg")
im_rgb= image
plt.imshow(originalImage)
#im_rgb = cvtColor(originalImage,cv2.COLOR_GRAY2RGB)
plt.imshow(im_rgb)
#image  = Image.open('playback-fm_colorize-photo_b44eb41b725ca6a61162e3e5ca696aca.jpeg')
#plt.imshow(lum_img)
model = tf.keras.models.load_model('model/')


#image.save('new_image1.png')
#new_image = image.resize((224, 224))
#new_image.save('image-size1.png')
resized_image = cv2.resize(im_rgb, (244, 244))
plt.imshow(im_rgb)
cv2.imwrite('new-sized.jpeg', im_rgb)
new_image=Image.open('1 no.jpeg')
new_image = np.resize(new_image,(224, 224))
new_image.save('image-size.png')
plt.imshow(new_image)
#backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ec4cc90253d1> in <module>
#      24 new_image=Image.open('1 no.jpeg')
#      25 new_image = np.resize(new_image,(224, 224))
# ---> 26 new_image.save('image-size.png')
#      27 plt.imshow(new_image)
#      28 #backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'

# %%
print(model.summary())
print("=-=--=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-")
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_28 (Conv2D)           (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 18, 18, 64)        0
# _________________________________________________________________
# dropout_141 (Dropout)        (None, 18, 18, 64)        0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 20736)             0
# ...

# %%
#import cv2

#originalImage = cv2.imread("1 no.jpeg")
#im_rgb = cv2.cvtColor(originalImage, cv2.COLOR_BGR2RGB)

# %%
tensorboard --logdir logs
# Out:
#   File "<ipython-input-53-575f178ee557>", line 1
#     tensorboard --logdir logs
#                             ^
# SyntaxError: invalid syntax

# %%
dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
x = img_to_array(new_image)
 
x = np.expand_dims(x, 3)
test= np.asarray(x)
backtorgb = cv2.cvtColor(test,cv2.COLOR_GRAY2RGB)
#preds = model.predict(backtorgb).argmax()
acuracy = model.predict(backtorgb)
print(acuracy)
#print(preds,"with conidince of:",acuracy.max()*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2c6059a86256> in <module>
#       5 backtorgb = cv2.cvtColor(test,cv2.COLOR_GRAY2RGB)
#       6 #preds = model.predict(backtorgb).argmax()
# ----> 7 acuracy = model.predict(backtorgb)
#       8 print(acuracy)
#       9 #print(preds,"with conidince of:",acuracy.max()*100)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     907         max_queue_size=max_queue_size,
#     908         workers=workers,
# --> 909         use_multiprocessing=use_multiprocessing)
#     910
#     911   def reset_metrics(self):
#
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imgplot = plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-64789df44e04> in <module>
# ----> 1 imgplot = plt.imshow(image)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-12ba6d47bd7e> in <module>
# ----> 1 plt.imshow(image)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...
